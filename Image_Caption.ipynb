# %% [markdown]
# <a href="https://colab.research.google.com/github/The-ML-Hero/Image-Caption-Using-Pytorch/blob/main/Image_Caption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
